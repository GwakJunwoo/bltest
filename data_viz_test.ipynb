# %%
import data_viz as viz
import plotly.express as px
import pandas as pd

# %%
df_line = pd.read_csv('sample.csv', encoding='EUC-KR')

def cum_profit(df):
    pct = df.pct_change()
    cum_pct = (1+pct).cumprod()-1
    cum_pct.iloc[0] = [0 for k in range(len(cum_pct.columns))]
    return cum_pct

df_line=df_line.set_index('Date')
df_line =cum_profit(df_line)

df_line.head()
# Out:
#                 ACWI      BOND      REET       USO       GLO       SPY  \
# Date
# 2019-05-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2019-06-03  0.001855 -0.000657  0.005671 -0.009910  0.003240 -0.002543
# 2019-06-04  0.018120 -0.000094  0.001890  0.005405  0.014039  0.019109
# 2019-06-05  0.021686  0.000469  0.016635 -0.029730  0.014039  0.027936
# 2019-06-07  0.037951  0.002066  0.023440  0.011712  0.020518  0.044974
#
#                  EWY      GOVT       LQD       VTV  ...    223190    325020  \
# Date                                                ...
# 2019-05-31  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2019-06-03  0.018895  0.002339  0.000000  0.009500  ...  0.017329  0.016023
# 2019-06-04  0.026093 -0.001170  0.000331  0.029652  ...  0.014793  0.017159
# 2019-06-05  0.015836 -0.002339 -0.000331  0.035985  ...  0.017329  0.014545
# 2019-06-07  0.025013  0.000780  0.006042  0.047596  ...  0.017751  0.011591
#
# ...

# %%
viz.line_plot(df_line, x=df_line.index, y=['ACWI', 'BOND', 'USO'], title="<b>Time-series<b>", data_source='Yahoo Finance')

# %%
df_facet_area = px.data.stocks(indexed=True)-1
df_facet_area.head()
# Out:
# company         GOOG      AAPL      AMZN        FB      NFLX      MSFT
# date
# 2018-01-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2018-01-08  0.018172  0.011943  0.061881 -0.040032  0.053526  0.015988
# 2018-01-15  0.032008  0.019771  0.053240 -0.029757  0.049860  0.020524
# 2018-01-22  0.066783 -0.019943  0.140676  0.016858  0.307681  0.066561
# 2018-01-29  0.008773 -0.082857  0.163374  0.018357  0.273537  0.040708

# %%
viz.facet_area_plot(df_facet_area, "company", title="<b>Time-series<b>", data_source='Yahoo Finance')

# %%
viz.scatter_plot(df_line, x='ACWI', y=['GOVT', 'USO', 'BOND'], title="<b>daily return vs ACWI<b>", data_source='Yahoo Finance')

# %%
df_bar = px.data.gapminder().query("country == 'Canada'")
df_bar.head()
# Out:
#     country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 240  Canada  Americas  1952    68.75  14785584  11367.16112       CAN      124
# 241  Canada  Americas  1957    69.96  17010154  12489.95006       CAN      124
# 242  Canada  Americas  1962    71.30  18985849  13462.48555       CAN      124
# 243  Canada  Americas  1967    72.13  20819767  16076.58803       CAN      124
# 244  Canada  Americas  1972    72.88  22284500  18970.57086       CAN      124

# %%
viz.bar_plot(df_bar, x='year', y='pop', title="<b>Canada<b>", data_source='gapminder')

# %%
df_group_bar = px.data.tips()
df_group_bar.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
viz.group_bar_plot(df_group_bar, x='sex', y='total_bill', color_column='smoker',
                   title="<b>Smoker's Tip<b>", data_source='Tips')

# %%
viz.pie_plot(df_group_bar, values='tip', names='day',
             title="<b>Tips day<b>", data_source='Tips', hole=0.3)

# %%
viz.box_plot(df_group_bar, x="sex", y="total_bill", color="smoker",
             title="<b>Smoker's Tips<b>", data_source='Tips')

# %%
df_tree_map = px.data.gapminder().query("year == 2007")
df_tree_map.head()
# Out:
#         country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 11  Afghanistan      Asia  2007   43.828  31889923    974.580338       AFG
# 23      Albania    Europe  2007   76.423   3600523   5937.029526       ALB
# 35      Algeria    Africa  2007   72.301  33333216   6223.367465       DZA
# 47       Angola    Africa  2007   42.731  12420476   4797.231267       AGO
# 59    Argentina  Americas  2007   75.320  40301927  12779.379640       ARG
#
#     iso_num
# 11        4
# 23        8
# 35       12
# 47       24
# 59       32

# %%
viz.tree_map(df_tree_map,  path=[px.Constant("world"), 'continent', 'country'], value='pop',
                color='lifeExp', title="<b>World Data<b>", data_source='Plotly')

# %%
viz.bubble_plot(df_tree_map, x='gdpPercap', y='lifeExp', size="pop", color="continent", log_x=True,
                title="<b>World Data<b>", data_source='Plotly')

# %%
array_heat_map = [[1, 20, 30],
                  [20, 1, 60],
                  [30, 60, 1]]

# %%
viz.heat_map(array_heat_map, title="<b>Sample<b>", data_source='Plotly')

# %%
viz.heat_map_v2(array_heat_map,title="<b>Sample<b>", data_source='Plotly')

# %%
category=[1, 5, 2, 2, 3]
score=['processing cost','mechanical properties','chemical stability',
        'thermal stability', 'device integration']

# %%
viz.radar_plot(category, score)
